# %% [markdown]
# # Question 1

# %%
#step 1
import pandas as pd
import numpy as np

# %%
#step 2 & 3
users = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', sep = '|')
users.head(10)
# Out:
#    user_id  age gender     occupation zip_code
# 0        1   24      M     technician    85711
# 1        2   53      F          other    94043
# 2        3   23      M         writer    32067
# 3        4   24      M     technician    43537
# 4        5   33      F          other    15213
# 5        6   42      M      executive    98101
# 6        7   57      M  administrator    91344
# 7        8   36      M  administrator    05201
# 8        9   29      M        student    01002
# 9       10   53      M         lawyer    90703

# %%
#step 4
users.groupby('occupation').age.mean()
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %%
#step 5
users.groupby('occupation').gender.count().sort_values(ascending = False)
# Out:
# occupation
# student          196
# other            105
# educator          95
# administrator     79
# engineer          67
# programmer        66
# librarian         51
# writer            45
# executive         32
# scientist         31
# artist            28
# technician        27
# marketing         26
# entertainment     18
# healthcare        16
# retired           14
# lawyer            12
# salesman          12
# none               9
# homemaker          7
# doctor             7
# Name: gender, dtype: int64

# %%
#step 6
users.groupby('occupation').age.agg(['min','max'])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %%
#step 7
users.groupby(['occupation','gender']).age.mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %%
#step 8
users[users.gender == 'M'].groupby('occupation').count()
# Out:
#                user_id  age  gender  zip_code
# occupation
# administrator       43   43      43        43
# artist              15   15      15        15
# doctor               7    7       7         7
# educator            69   69      69        69
# engineer            65   65      65        65
# entertainment       16   16      16        16
# executive           29   29      29        29
# healthcare           5    5       5         5
# homemaker            1    1       1         1
# lawyer              10   10      10        10
# librarian           22   22      22        22
# marketing           16   16      16        16
# none                 5    5       5         5
# other               69   69      69        69
# programmer          60   60      60        60
# retired             13   13      13        13
# salesman             9    9       9         9
# scientist           28   28      28        28
# student            136  136     136       136
# ...

# %%
users[users.gender == 'F'].groupby('occupation').count()
# Out:
#                user_id  age  gender  zip_code
# occupation
# administrator       36   36      36        36
# artist              13   13      13        13
# educator            26   26      26        26
# engineer             2    2       2         2
# entertainment        2    2       2         2
# executive            3    3       3         3
# healthcare          11   11      11        11
# homemaker            6    6       6         6
# lawyer               2    2       2         2
# librarian           29   29      29        29
# marketing           10   10      10        10
# none                 4    4       4         4
# other               36   36      36        36
# programmer           6    6       6         6
# retired              1    1       1         1
# salesman             3    3       3         3
# scientist            3    3       3         3
# student             60   60      60        60
# technician           1    1       1         1
# ...

# %% [markdown]
# # Question - 2

# %%
#step 1
import pandas as pd 
import numpy as np

# %%
#step 2 & 3
euro12 = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv')
euro12
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#step 4
euro12.Goals
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
#step 5
euro12.Team.count()
# Out:
# 16

# %%
#step 6
euro12.shape[1]
# Out:
# 35

# %%
#step 7
discipline = euro12[['Team', 'Yellow Cards', 'Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
#step 8
discipline.sort_values(['Yellow Cards','Red Cards'])
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
#step 9
euro12['Yellow Cards'].mean()
# Out:
# 7.4375

# %%
#step 10
euro12[euro12['Goals'] > 6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %%
#step 11
euro12[euro12.Team.str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %%
#step 12
euro12.head(7)
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
# 5         Germany     10               32                32             47.8%
# 6          Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# ...

# %%
#step 13
euro12.iloc[:, :-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#step 14
euro12.loc[euro12.Team.isin(['England', 'Italy', 'Russia']), ['Team', 'Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# # Question 3

# %%
#step 1
import pandas as pd
import numpy as np

# %%
#step 2
First = pd.Series(np.random.randint(1,5,100))
second = pd.Series(np.random.randint(1,4,100))
third = pd.Series(np.random.randint(10000,30000,100))

# %%
#step 3
df = pd.concat([First, second, third], axis = 1)
df
# Out:
#     0  1      2
# 0   2  3  18766
# 1   1  1  26083
# 2   4  2  16117
# 3   3  3  14427
# 4   2  2  17004
# .. .. ..    ...
# 95  1  2  10309
# 96  4  3  26575
# 97  1  1  23638
# 98  2  3  16126
# 99  1  3  16225
#
# [100 rows x 3 columns]

# %%
#step 4
df.columns = ['bedrs', 'bathrs', ' price_sqr_meter']
df
# Out:
#     bedrs  bathrs   price_sqr_meter
# 0       2       3             18766
# 1       1       1             26083
# 2       4       2             16117
# 3       3       3             14427
# 4       2       2             17004
# ..    ...     ...               ...
# 95      1       2             10309
# 96      4       3             26575
# 97      1       1             23638
# 98      2       3             16126
# 99      1       3             16225
#
# [100 rows x 3 columns]

# %%
#step 5
BigColumn = pd.concat([First, second, third], axis = 0)
BigColumn
# Out:
# 0         2
# 1         1
# 2         4
# 3         3
# 4         2
#       ...
# 95    10309
# 96    26575
# 97    23638
# 98    16126
# 99    16225
# Length: 300, dtype: int32

# %%
#step 6
len(BigColumn)
# Out:
# 300

# %%
#step 7
BigColumn.reset_index(drop = True, inplace = True)
BigColumn
# Out:
# 0          2
# 1          1
# 2          4
# 3          3
# 4          2
#        ...
# 295    10309
# 296    26575
# 297    23638
# 298    16126
# 299    16225
# Length: 300, dtype: int32

# %% [markdown]
# # Question 4

# %%
#step -1
import pandas as pd
import numpy as np
import datetime as dt

# %%
#step 2
data = pd.read_csv('wind.txt', sep = '\s+')
data
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0     61   1   1  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1     61   1   2  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2     61   1   3  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3     61   1   4  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4     61   1   5  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...   ..  ..  ..    ...    ...    ...    ...    ...    ...    ...    ...
# 6569  78  12  27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# ...

# %%
#step -3
data = pd.to_datetime(data[["Yr", "Mo","Dy"]].astype(str).agg('-'.join, axis = 1))
data = data.drop(columns = ["Yr", "Mo", "Dy"])
data.head()
# Out:
# 0   2061-01-01
# 1   2061-01-02
# 2   2061-01-03
# 3   2061-01-04
# 4   2061-01-05
# dtype: datetime64[ns]

# %%
#step -4

# %%
#step 5

# %%
#step 6
data.isnull().sum()
# Out:
# 0

# %%
#step 7
data.notnull().sum()
# Out:
# 6574

# %%
#step 8
data.mean()
# Out:
# Timestamp('2031-02-07 20:44:10.441131520')

# %%
#step 9
loc_stats = pd.DataFrame()
loc_stats['min'] = data.min()
loc_stats['max'] = data.max()
loc_stats['mean'] = data.mean()
loc_stats['std'] = data.std()
loc_stats
# Out:
# Empty DataFrame
# Columns: [min, max, mean, std]
# Index: []

# %%
#step 10
day_stats = pd.DataFrame()
day_stats['min'] = data.min()
day_stats['max'] = data.max()
day_stats['mean'] = data.mean()
day_stats['std'] = data.std()

day_stats.head()
# Out:
# Empty DataFrame
# Columns: [min, max, mean, std]
# Index: []

# %%
#step 12

# %% [markdown]
# # Question 5

# %%
#step 1
import pandas as pd

# %%
#step 2 & 3
chipo = pd.read_csv("q_5.txt", sep = '\t')
chipo.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
#step 4
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
#step 5
chipo.shape[0]
# Out:
# 4622

# %%
#step 6
chipo.shape[1]
# Out:
# 5

# %%
#step 7
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#step 8
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
#step 9 & 10
chipo.item_name.value_counts().head(1)
# Out:
# Chicken Bowl    726
# Name: item_name, dtype: int64

# %%
#step 11
chipo.choice_description.value_counts().head()
# Out:
# [Diet Coke]                                                                          134
# [Coke]                                                                               123
# [Sprite]                                                                              77
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]                42
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]     40
# Name: choice_description, dtype: int64

# %%
#step 12
chipo.quantity.sum()
# Out:
# 4972

# %%
#step 13
chipo['item_price'].dtype
# Out:
# dtype('O')

# %%
chipo['item_price'] = chipo['item_price'].apply(lambda x: float())
chipo['item_price'].dtype
# Out:
# dtype('float64')

# %%
#step 14
chipo['item_price'].sum()
# Out:
# 0.0

# %%
#step 15
len(chipo.groupby('order_id').agg({'order_id':'count'}))
# Out:
# 1834

# %%
#step 16
chipo.groupby('order_id').agg({'item_price':'mean'}).mean()
# Out:
# item_price    0.0
# dtype: float64

# %%
#step 17
chipo.item_name.value_counts().count()
# Out:
# 50

# %% [markdown]
# # Question 6

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
USMarrageDivorce = pd.read_csv('us-marriages-divorces.csv')
USMarrageDivorce.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                145 non-null    int64
#  1   Marriages           141 non-null    float64
#  2   Divorces            141 non-null    float64
#  3   Population          145 non-null    int64
#  4   Marriages_per_1000  141 non-null    float64
#  5   Divorces_per_1000   141 non-null    float64
# dtypes: float64(4), int64(2)
# memory usage: 6.9 KB

# %%
USMarrageDivorce.head()
# Out:
#    Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0  1867   357000.0   10000.0    36970000                 9.7
# 1  1868   345000.0   10000.0    37885000                 9.1
# 2  1869   348000.0   11000.0    38870000                 9.0
# 3  1870   352000.0   11000.0    39905000                 8.8
# 4  1871   359000.0   12000.0    41010000                 8.8
#
#    Divorces_per_1000
# 0                0.3
# 1                0.3
# 2                0.3
# 3                0.3
# 4                0.3

# %%
years = USMarrageDivorce['Year']
marriages = USMarrageDivorce['Marriages_per_1000']
divorces = USMarrageDivorce['Divorces_per_1000']
USMarrageDivorce = plt.figure(figsize= (12,6))
USMarrageDivorce = plt.plot(years, marriages, label ='Marriages')
USMarrageDivorce = plt.plot(years, divorces, label = 'Divorces')
USMarrageDivorce = plt.title("Number of marriages and divorces per capita in the U.S. between 1867 and 2014", fontsize=16)
USMarrageDivorce = plt.xlabel("Years", fontsize=14)
USMarrageDivorce = plt.legend(fontsize = 12, loc = "upper left")
USMarrageDivorce = plt.grid(True)
USMarrageDivorce

# %% [markdown]
# # Question 7

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
USMarrageDivorce = pd.read_csv('us-marriages-divorces.csv')
USMarrageDivorce.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145 entries, 0 to 144
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                145 non-null    int64
#  1   Marriages           141 non-null    float64
#  2   Divorces            141 non-null    float64
#  3   Population          145 non-null    int64
#  4   Marriages_per_1000  141 non-null    float64
#  5   Divorces_per_1000   141 non-null    float64
# dtypes: float64(4), int64(2)
# memory usage: 6.9 KB

# %%
AssignVar = USMarrageDivorce.loc[USMarrageDivorce.Year.isin([1900,1950,2000]), ['Year', 'Marriages_per_1000', 'Divorces_per_1000']]
AssignVar
# Out:
#      Year  Marriages_per_1000  Divorces_per_1000
# 33   1900                 9.3                0.7
# 83   1950                11.0                2.5
# 133  2000                 8.2                3.3

# %%
AssignVar = AssignVar[AssignVar['Year'].apply(lambda x: x in [1900, 1950, 2000])]
years = AssignVar['Year']
marriages = AssignVar['Marriages_per_1000']
divorces = AssignVar['Divorces_per_1000']
AssignVar = plt.figure(figsize= (12,6))
AssignVar = plt.bar(years, marriages, label ='Marriages')
AssignVar = plt.bar(years, divorces, label = 'Divorces')
AssignVar = plt.title("Number of marriages and divorces per capita in the U.S. between 1990,1950 and 2000", fontsize=16)
AssignVar = plt.xlabel("Years", fontsize=14)

AssignVar = plt.legend(fontsize = 12, loc = "upper left")
AssignVar

# %% [markdown]
# # Question 8

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
deadlist_actor = pd.read_csv('actor_kill_counts.csv')
deadlist_actor
# Out:
#                    Actor  Count
# 0  Arnold Schwarzenegger    369
# 1           Chow Yun-Fat    295
# 2         Clint Eastwood    207
# 3             Clive Owen    194
# 4         Dolph Lundgren    239
# 5                 Jet Li    201
# 6           Nicolas Cage    204
# 7     Sylvester Stallone    267
# 8    Tomisaburo Wakayama    226
# 9          Wesley Snipes    193

# %%
actorName = deadlist_actor['Actor']
killCount = deadlist_actor['Count']
deadlist_actor = plt.figure(figsize= (12,6))
deadlist_actor = plt.barh(actorName, killCount,label ='actor')
#deadlist_actor = plt.barh(killCount, width=0.5 ,label = 'kill Count')
deadlist_actor = plt.title("The deadliest actors in Hollywood", fontsize=18)
deadlist_actor = plt.xlabel("kill count", fontsize=14)
deadlist_actor = plt.legend(fontsize = 12, loc = "upper right")
deadlist_actor

# %% [markdown]
# # Question 9

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Roman = pd.read_csv('roman-emperor-reigns.csv')
Roman
# Out:
#            Emperor  Length_of_Reign         Cause_of_Death
# 0         Augustus            40.58  Possibly assassinated
# 1         Tiberius            22.50  Possibly assassinated
# 2         Caligula             4.83           Assassinated
# 3         Claudius            13.75  Possibly assassinated
# 4             Nero            13.67                Suicide
# ..             ...              ...                    ...
# 63   Valentinian I            11.00         Natural causes
# 64          Valens            14.00       Killed in battle
# 65         Gratian            16.00           Assassinated
# 66  Valentinian II            17.00  Possibly assassinated
# 67    Theodosius I            16.00         Natural causes
#
# [68 rows x 3 columns]

# %%
RomanAssasinated = Roman.loc[Roman.Cause_of_Death.isin(['Assassinated']), ['Cause_of_Death', 'Emperor']]
RomanAssasinated
# Out:
#    Cause_of_Death             Emperor
# 2    Assassinated            Caligula
# 5    Assassinated               Galba
# 7    Assassinated           Vitellius
# 10   Assassinated            Domitian
# 17   Assassinated            Commodus
# 18   Assassinated            Pertinax
# 21   Assassinated           Caracalla
# 22   Assassinated                Geta
# 24   Assassinated          Elagabalus
# 25   Assassinated   Severus Alexander
# 26   Assassinated         Maximinus I
# 29   Assassinated            Pupienus
# 30   Assassinated            Balbinus
# 35   Assassinated  Trebonianus Gallus
# 36   Assassinated            Aemilian
# 38   Assassinated           Gallienus
# 41   Assassinated            Aurelian
# 43   Assassinated             Florian
# 44   Assassinated              Probus
# 52   Assassinated          Severus II
# 59   Assassinated          Constans I
# 65   Assassinated             Gratian

# %%
Romansfig = plt.figure(figsize=(7,7))
patches, texts = plt.pie(Roman.Length_of_Reign)
Romansfig = plt.legend(Roman.Emperor)
Romansfig = plt.show()
Romansfig

# %% [markdown]
# # Question 10

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ScatterPlot = pd.read_csv('arcade-revenue-vs-cs-doctorates.csv')
ScatterPlot
# Out:
#    Year  Total Arcade Revenue (billions)  \
# 0  2000                            1.196
# 1  2001                            1.176
# 2  2002                            1.269
# 3  2003                            1.240
# 4  2004                            1.307
# 5  2005                            1.435
# 6  2006                            1.601
# 7  2007                            1.654
# 8  2008                            1.803
# 9  2009                            1.734
#
#    Computer Science Doctorates Awarded (US)
# 0                                       861
# 1                                       830
# 2                                       809
# 3                                       867
# 4                                       948
# 5                                      1129
# 6                                      1453
# 7                                      1656
# 8                                      1787
# 9                                      1611

# %%
years = ScatterPlot['Year']
arcade = ScatterPlot['Total Arcade Revenue (billions)']
computerAward = ScatterPlot['Computer Science Doctorates Awarded (US)']
ScatterPlot = plt.figure(figsize= (12,6))
ScatterPlot = plt.scatter(years, arcade, label ='Total Arcade Revenue (billions)')
ScatterPlot = plt.scatter(years, computerAward, label = 'Computer Science Doctorates Awarded (US)')
ScatterPlot = plt.title("Total revenue earned by arcades and the number of Computer Science PhDs awarded in the U.S. between 2000 and 2009.", fontsize=14)
ScatterPlot = plt.xlabel("Years", fontsize=14)
ScatterPlot = plt.legend(fontsize = 12, loc = "upper left")
ScatterPlot = plt.grid(True)
ScatterPlot

# %% [markdown]
# # References

# %%
https://www.geeksforgeeks.org/bar-plot-in-matplotlib/
https://www.geeksforgeeks.org/draw-a-horizontal-bar-chart-with-matplotlib/
https://www.geeksforgeeks.org/pie-plot-using-plotly-in-python/
